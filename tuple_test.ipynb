# %%
t = (1, 2, 3)
mixed_tuple = (1, 'Hello', 3.14)

print(mixed_tuple[0])
# Out:
# 1

# %%
print(t[1])
print(t[2])
print(t[1:])
# Out:
# 2
# 3
# (2, 3)

# %%
print(t.count(3))
print(t.index(2))
# Out:
# 1
# 1
