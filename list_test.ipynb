# %%
my_list=[1 , 200.2 , "Hello" , True , ]
print(my_list)
# Out:
# [1, 200.2, 'Hello', True]

# %%
print(my_list[1:])
# Out:
# [200.2, 'Hello', True]

# %%
another_list=[1,2,3,4,5]
print(my_list + another_list)
# Out:
# [1, 200.2, 'Hello', True, 1, 2, 3, 4, 5]

# %%
another_list[0]=100
print(another_list)
# Out:
# [100, 2, 3, 4, 5]

# %%
print(another_list * 4)
# Out:
# [100, 2, 3, 4, 5]

# %%
my_list.append(6)
print(my_list)
# Out:
# [1, 200.2, 'Hello', True, 6]

# %%
my_list.pop(3)
print(my_list)
# Out:
# [1, 200.2, 'Hello']

# %%
my_list.insert(3, " rauma")
print(my_list)
# Out:
# [1, 200.2, 'Hello', ' rauma']

# %%
my_list.remove(200.2)
print(my_list)
# Out:
# [1, 'Hello', ' rauma']

# %%
nem = [1,2,3,8,4]
nem.sort()
print(nem)
# Out:
# [1, 2, 3, 4, 8]

# %%
nem.reverse()
print(nem)
# Out:
# [8, 4, 3, 2, 1]

# %%
nem.clear()
print(nem)
# Out:
# []
