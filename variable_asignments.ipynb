# %%
a = 3 
b = 9 
nem = a + b
print(nem)
a = a + a #giờ a đã thành 6 
a += 10 ## a = a + 10
print("a:", a)
# Out:
# 12
# a: 16

# %%
print(nem * 2)
type(nem)
# Out:
# 24
# int

# %%
test = 20.8 
type(test)
# Out:
# float

# %%
income = 1000
tax_rate = 0.2
total = income * tax_rate
print("total:", total)
# Out:
# total: 200.0
